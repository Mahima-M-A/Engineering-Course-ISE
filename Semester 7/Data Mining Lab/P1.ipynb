# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('CustomerData.csv')

# %%
df.head()
# Out:
#    CustID    Age  Gender    Country Employed    Income  \
# 0       1   37.0    Male        USA     True       NaN
# 1       2   44.0     NaN     Russia    False  463034.0
# 2       3  900.0  Female      India     True  402865.0
# 3       4   46.0     NaN        USA     True       NaN
# 4       5   19.0  Female  Australia     True  221868.0
#
#    ItemsPurchased(monthly) ProductType    PaymentType     Mode
# 0                     99.0    BabyCare           Cash  Offline
# 1                     21.0    BabyCare  Bank Transfer      NaN
# 2                     31.0     Medical            UPI  Offline
# 3                     21.0    BabyCare            UPI  Offline
# 4                     45.0     Medical  Bank Transfer   Online

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
# CustID                     50 non-null int64
# Age                        43 non-null float64
# Gender                     42 non-null object
# Country                    46 non-null object
# Employed                   47 non-null object
# Income                     46 non-null float64
# ItemsPurchased(monthly)    46 non-null float64
# ProductType                46 non-null object
# PaymentType                47 non-null object
# Mode                       46 non-null object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.8+ KB

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Renoving anomalous data

# %%
df.loc[df['Age'] > 100, 'Age'] = np.nan

# %%
df.head()
# Out:
#    CustID   Age  Gender    Country Employed    Income  \
# 0       1  37.0    Male        USA     True       NaN
# 1       2  44.0     NaN     Russia    False  463034.0
# 2       3   NaN  Female      India     True  402865.0
# 3       4  46.0     NaN        USA     True       NaN
# 4       5  19.0  Female  Australia     True  221868.0
#
#    ItemsPurchased(monthly) ProductType    PaymentType     Mode
# 0                     99.0    BabyCare           Cash  Offline
# 1                     21.0    BabyCare  Bank Transfer      NaN
# 2                     31.0     Medical            UPI  Offline
# 3                     21.0    BabyCare            UPI  Offline
# 4                     45.0     Medical  Bank Transfer   Online

# %% [markdown]
# Removing null values

# %%
df.isnull().sum()
# Out:
# CustID                     0
# Age                        9
# Gender                     8
# Country                    4
# Employed                   3
# Income                     4
# ItemsPurchased(monthly)    4
# ProductType                4
# PaymentType                3
# Mode                       4
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(int(df['Age'].mean()))
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Country'] = df['Country'].fillna(df['Country'].mode()[0])
df['Employed'] = df['Employed'].fillna(df['Employed'].mode()[0])
df['Income'] = df['Income'].fillna(df['Income'].mean())
df['ItemsPurchased(monthly)'] = df['ItemsPurchased(monthly)'].fillna(int(df['ItemsPurchased(monthly)'].mean()))
df['ProductType'] = df['ProductType'].fillna(df['ProductType'].mode()[0])
df['PaymentType'] = df['PaymentType'].fillna(df['PaymentType'].mode()[0])
df['Mode'] = df['Mode'].fillna(df['Mode'].mode()[0])

# %%
df.head()
# Out:
#    CustID   Age  Gender    Country  Employed         Income  \
# 0       1  37.0    Male        USA      True  242613.630435
# 1       2  44.0    Male     Russia     False  463034.000000
# 2       3  50.0  Female      India      True  402865.000000
# 3       4  46.0    Male        USA      True  242613.630435
# 4       5  19.0  Female  Australia      True  221868.000000
#
#    ItemsPurchased(monthly) ProductType    PaymentType     Mode
# 0                     99.0    BabyCare           Cash  Offline
# 1                     21.0    BabyCare  Bank Transfer   Online
# 2                     31.0     Medical            UPI  Offline
# 3                     21.0    BabyCare            UPI  Offline
# 4                     45.0     Medical  Bank Transfer   Online

# %%
df.isnull().sum()
# Out:
# CustID                     0
# Age                        0
# Gender                     0
# Country                    0
# Employed                   0
# Income                     0
# ItemsPurchased(monthly)    0
# ProductType                0
# PaymentType                0
# Mode                       0
# dtype: int64

# %% [markdown]
# Scaling the values

# %%
scaler = MinMaxScaler()

# %%
df[['Income', 'ItemsPurchased(monthly)']] = scaler.fit_transform(df[['Income', 'ItemsPurchased(monthly)']])

# %%
df.head()
# Out:
#    CustID   Age  Gender    Country  Employed    Income  \
# 0       1  37.0    Male        USA      True  0.470969
# 1       2  44.0    Male     Russia     False  0.925669
# 2       3  50.0  Female      India      True  0.801548
# 3       4  46.0    Male        USA      True  0.470969
# 4       5  19.0  Female  Australia      True  0.428174
#
#    ItemsPurchased(monthly) ProductType    PaymentType     Mode
# 0                 1.000000    BabyCare           Cash  Offline
# 1                 0.187500    BabyCare  Bank Transfer   Online
# 2                 0.291667     Medical            UPI  Offline
# 3                 0.187500    BabyCare            UPI  Offline
# 4                 0.437500     Medical  Bank Transfer   Online

# %% [markdown]
# Discretizing or binning the values

# %%
bins = [0, 12, 19, 59, 100]
labels = ['Child', 'Teen', 'Middle-Aged', 'Senior-Citizen']

df['CustCategory'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
df.head()
# Out:
#    CustID   Age  Gender    Country  Employed    Income  \
# 0       1  37.0    Male        USA      True  0.470969
# 1       2  44.0    Male     Russia     False  0.925669
# 2       3  50.0  Female      India      True  0.801548
# 3       4  46.0    Male        USA      True  0.470969
# 4       5  19.0  Female  Australia      True  0.428174
#
#    ItemsPurchased(monthly) ProductType    PaymentType     Mode CustCategory
# 0                 1.000000    BabyCare           Cash  Offline  Middle-Aged
# 1                 0.187500    BabyCare  Bank Transfer   Online  Middle-Aged
# 2                 0.291667     Medical            UPI  Offline  Middle-Aged
# 3                 0.187500    BabyCare            UPI  Offline  Middle-Aged
# 4                 0.437500     Medical  Bank Transfer   Online         Teen
